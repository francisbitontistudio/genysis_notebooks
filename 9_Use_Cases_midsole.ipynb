# %% [markdown]
# # Use_Cases: 3D Printed Mid Sole
# ![image.png](attachment:image.png)

# %%
import genysis
t = "eyJhbGciOiJIU.U892JiUy" # replace with your valid token
# Out:
# Welcome to GENYSIS

# %%
# uploade required files to server
genysis.upload("models/sole_example.json","sole_example.json",t)
# Out:
# ('uploading file size:', 0.076, 'MB')
# [==================================================]100%
# successfully uploaded models/sole_example.json as sole_example.json
# {u'message': u'sole_example.json uploaded to test@test.com/sole_example.json'}

# %%
# create 3D conformal lattice grid from given surface defination
conformalLattice = genysis.conformalLattice() # initialize conformal lattice class
conformalLattice.setEPSILON(0.1) # a tolerance value to join and clean up small lines

conformalLattice.setSurfaces("sole_example.json") # input volume surfaces defination 
conformalLattice.setUVW(50,6,5) # uvw resolution for conformal grid
conformalLattice.setGridOutput("grid_example.json") # output file name
conformalLattice.genGrid(t) # call the api to generate the grid

genysis.visualize("grid_example.json",t,True,500,500)
# Out:
# ('request: ', '{"surfaces": "sole_example.json", "filename": "grid_example.json", "u": 50, "t": "eyJhbGciOiJIU.U892JiUy", "w": 5, "v": 6}')
# ('response: ', u'["grid_example.json"]')
# https://studiobitonti.appspot.com/apps/visualize?name=grid_example.json&t=eyJhbGciOiJIU.U892JiUy
#         <iframe
#             width="500"
#             height="500"
#             src="https://studiobitonti.appspot.com/apps/visualize?name=grid_example.json&t=eyJhbGciOiJIU.U892JiUy"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# 'https://studiobitonti.appspot.com/apps/visualize?name=grid_example.json&t=eyJhbGciOiJIU.U892JiUy'

# %%
# generate two different cells to apply on the 3D grid
cell_0 = 'cell_0.obj'
cell_1 = 'cell_1.obj'

genysis.genLatticeUnit(case=2,chamfer=0,centerChamfer=0,bendIn=0.1,cBendIn=0,connectPt=0,output=cell_0,token=t)
genysis.visualize(cell_0,t,True,300,300)

genysis.genLatticeUnit(case=2,chamfer=0,centerChamfer=0,bendIn=1,cBendIn=0,connectPt=0,output=cell_1,token=t)
genysis.visualize(cell_1,t,True,300,300)
# Out:
# ('request: ', '{"case": 2, "cBendIn": 0, "chamfer": 0, "bendIn": 0.1, "centerChamfer": 0, "filename": "cell_0.obj", "t": "eyJhbGciOiJIU.U892JiUy", "connectPt": 0}')
# ('response: ', u'["cell_0.obj"]')
# https://studiobitonti.appspot.com/apps/visualize?name=cell_0.obj&t=eyJhbGciOiJIU.U892JiUy
#         <iframe
#             width="300"
#             height="300"
#             src="https://studiobitonti.appspot.com/apps/visualize?name=cell_0.obj&t=eyJhbGciOiJIU.U892JiUy"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# ('request: ', '{"case": 2, "cBendIn": 0, "chamfer": 0, "bendIn": 1, "centerChamfer": 0, "filename": "cell_1.obj", "t": "eyJhbGciOiJIU.U892JiUy", "connectPt": 0}')
# ('response: ', u'["cell_1.obj"]')
# https://studiobitonti.appspot.com/apps/visualize?name=cell_1.obj&t=eyJhbGciOiJIU.U892JiUy
#         <iframe
#             width="300"
#             height="300"
#             src="https://studiobitonti.appspot.com/apps/visualize?name=cell_1.obj&t=eyJhbGciOiJIU.U892JiUy"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# 'https://studiobitonti.appspot.com/apps/visualize?name=cell_1.obj&t=eyJhbGciOiJIU.U892JiUy'

# %%
# example of applying one type of lattice unit to the grid
conformalLattice.setComponent('cell_0.obj')
conformalLattice.setOutput('conformalLattice_0.obj')
conformalLattice.populateLattice(t)
genysis.visualize('conformalLattice_0.obj',t,True,500,500)
# Out:
# ('request: ', '{"EPSILON": 0.1, "component": "cell_0.obj", "filename": "conformalLattice_0.obj", "blendTargets": [], "boxes": "grid_example.json", "t": "eyJhbGciOiJIU.U892JiUy"}')
# ('response: ', u'["conformalLattice_0.obj"]')
# https://studiobitonti.appspot.com/apps/visualize?name=conformalLattice_0.obj&t=eyJhbGciOiJIU.U892JiUy
#         <iframe
#             width="500"
#             height="500"
#             src="https://studiobitonti.appspot.com/apps/visualize?name=conformalLattice_0.obj&t=eyJhbGciOiJIU.U892JiUy"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# 'https://studiobitonti.appspot.com/apps/visualize?name=conformalLattice_0.obj&t=eyJhbGciOiJIU.U892JiUy'

# %%
# example of applying two typle of lattice units using a point attractor
conformalLattice.attractorSet = [] # clean up added attractors
conformalLattice.setComponent('cell_0.obj')
conformalLattice.setOutput('conformalLattice_1.obj')
conformalLattice.addPointAttractor(component="cell_1.obj",point=[0,0,0],range=80)
conformalLattice.populateLattice(t)
genysis.visualize('conformalLattice_1.obj',t,True,500,500)
# Out:
# ('request: ', '{"EPSILON": 0.1, "component": "cell_0.obj", "filename": "conformalLattice_1.obj", "blendTargets": [{"attractor": {"range": 80, "point": [0, 0, 0]}, "component": "cell_1.obj"}], "boxes": "grid_example.json", "t": "eyJhbGciOiJIU.U892JiUy"}')
# ('response: ', u'["conformalLattice_1.obj"]')
# https://studiobitonti.appspot.com/apps/visualize?name=conformalLattice_1.obj&t=eyJhbGciOiJIU.U892JiUy
#         <iframe
#             width="500"
#             height="500"
#             src="https://studiobitonti.appspot.com/apps/visualize?name=conformalLattice_1.obj&t=eyJhbGciOiJIU.U892JiUy"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# 'https://studiobitonti.appspot.com/apps/visualize?name=conformalLattice_1.obj&t=eyJhbGciOiJIU.U892JiUy'

# %%
# example of applying two typle of lattice units using a plane attractor
conformalLattice.attractorSet = [] # clean up added attractors
conformalLattice.setComponent('cell_0.obj')
conformalLattice.setOutput('conformalLattice_2.obj')
conformalLattice.addPlaneAttractor(component="cell_1.obj",plane=[1,0,0,-100],range=200)
conformalLattice.populateLattice(t)
genysis.visualize('conformalLattice_2.obj',t,True,500,500)
# Out:
# ('request: ', '{"EPSILON": 0.1, "component": "cell_0.obj", "filename": "conformalLattice_2.obj", "blendTargets": [{"attractor": {"range": 200, "plane": [1, 0, 0, -100]}, "component": "cell_1.obj"}], "boxes": "grid_example.json", "t": "eyJhbGciOiJIU.U892JiUy"}')
# ('response: ', u'["conformalLattice_2.obj"]')
# https://studiobitonti.appspot.com/apps/visualize?name=conformalLattice_2.obj&t=eyJhbGciOiJIU.U892JiUy
#         <iframe
#             width="500"
#             height="500"
#             src="https://studiobitonti.appspot.com/apps/visualize?name=conformalLattice_2.obj&t=eyJhbGciOiJIU.U892JiUy"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# 'https://studiobitonti.appspot.com/apps/visualize?name=conformalLattice_2.obj&t=eyJhbGciOiJIU.U892JiUy'

# %%
# example of applying two typle of lattice units using a curve attractor
conformalLattice.attractorSet = [] # clean up added attractors
conformalLattice.setComponent('cell_0.obj')
conformalLattice.setOutput('conformalLattice_3.obj')
conformalLattice.addCurveAttractor(component="cell_1.obj",curve=[[-200,20,0],[0,-20,0],[100,20,0],[150,0,0]],range=30)
conformalLattice.populateLattice(t)
genysis.visualize('conformalLattice_3.obj',t,True,500,500)
# Out:
# ('request: ', '{"EPSILON": 0.1, "component": "cell_0.obj", "filename": "conformalLattice_3.obj", "blendTargets": [{"attractor": {"range": 30, "curve": [[-200, 20, 0], [0, -20, 0], [100, 20, 0], [150, 0, 0]]}, "component": "cell_1.obj"}], "boxes": "grid_example.json", "t": "eyJhbGciOiJIU.U892JiUy"}')
# ('response: ', u'["conformalLattice_3.obj"]')
# https://studiobitonti.appspot.com/apps/visualize?name=conformalLattice_3.obj&t=eyJhbGciOiJIU.U892JiUy
#         <iframe
#             width="500"
#             height="500"
#             src="https://studiobitonti.appspot.com/apps/visualize?name=conformalLattice_3.obj&t=eyJhbGciOiJIU.U892JiUy"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# 'https://studiobitonti.appspot.com/apps/visualize?name=conformalLattice_3.obj&t=eyJhbGciOiJIU.U892JiUy'

# %%
# use marching cube to create final tubed lattice geometry
genysis.marchingCube(
    'conformalLattice_3.obj', # input obj lines file
    200, # meshing resolution
    1, # member thickness
    "Marching_Cube_Example.stl", # output file name
    t, # token
    preview=True # set to False to generate printable water-tight version of geometry
)

genysis.visualize("Marching_Cube_Example.stl",t,True)
# Out:
# ('request: ', '{"memberThickness": 1, "lines": "conformalLattice_3.obj", "filename": "Marching_Cube_Example.stl", "t": "eyJhbGciOiJIU.U892JiUy", "preview": true, "resolution": 200}')
# ('response: ', u'["Marching_Cube_Example.stl"]')
# https://studiobitonti.appspot.com/apps/visualize?name=Marching_Cube_Example.stl&t=eyJhbGciOiJIU.U892JiUy
#         <iframe
#             width="800"
#             height="600"
#             src="https://studiobitonti.appspot.com/apps/visualize?name=Marching_Cube_Example.stl&t=eyJhbGciOiJIU.U892JiUy"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# 'https://studiobitonti.appspot.com/apps/visualize?name=Marching_Cube_Example.stl&t=eyJhbGciOiJIU.U892JiUy'
